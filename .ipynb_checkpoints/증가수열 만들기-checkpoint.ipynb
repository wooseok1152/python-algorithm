# %%
import sys

#sys.stdin = open(r"C:\Users\my\Desktop\Documents\파이썬 알고리즘 문제풀이(코딩테스트 대비)\섹션 4\9. 증가수열 만들기\in2.txt")

n = int(input())
input_list = list(map(int, input().split()))
letter_list = []
count = 0

if input_list[0] < input_list[-1]:
    
    picked_value = input_list.pop(0)
    count = count + 1
    letter_list.append("L")
    
else:
    
    picked_value = input_list.pop(-1)
    count = count + 1
    letter_list.append("R")
    
while True:
    
    if len(input_list) == 1:
        
        if input_list[0] > picked_value :
            
            count = count + 1
            letter_list.append("L")
            break
        
        else :
            
            break

    elif input_list[0] < picked_value and input_list[-1] < picked_value:
        
        break
    
    elif input_list[0] > picked_value and input_list[-1] < picked_value:
        
        picked_value = input_list.pop(0)
        count = count + 1
        letter_list.append("L")
        
    elif input_list[-1] > picked_value and input_list[0] < picked_value:
        
        picked_value = input_list.pop(-1)
        count = count + 1
        letter_list.append("R")
        
    elif input_list[0] > picked_value and input_list[-1] > picked_value:
        
        if input_list[0] < input_list[-1]:
            
            picked_value = input_list.pop(0)
            count = count + 1
            letter_list.append("L")
            
        else :
            
            picked_value = input_list.pop(-1)
            count = count + 1
            letter_list.append("R")
            
print(count)
letter = ""
for i in letter_list:
    
    letter = letter+i

print(letter)
